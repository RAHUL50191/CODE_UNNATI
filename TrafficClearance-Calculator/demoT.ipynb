# %%
from ultralytics import YOLO
from ultralytics.solutions import object_counter
import cv2
import pandas as pd
import time

# Load YOLO models
models = [YOLO("yolov8n.pt") for _ in range(4)]

# Open video captures for each lane
caps = [cv2.VideoCapture(f"lane{i + 1}.webm") for i in range(4)]

# Define region points for three lanes spanning half of the screen
region_points = [
    [(20, 400), (540, 400), (520, 740), (20, 740)],  # Left half of the screen
    [(540, 400), (1060, 400), (1040, 740), (540, 740)],  # Middle half of the screen
    [(20, 400), (1060, 400), (1040, 740), (20, 740)]  # Right half of the screen
]

# Classes to count
classes_to_count=[1,2,5,7]
print(models[0].names)
def filter_dict_by_keys(input_dict, keys_list):
    return {key: input_dict[key] for key in keys_list}
 

# Initialize Object Counters for each lane
def initialize_counters(model, region_points):
    counters = []
    for points in region_points:
        counter = object_counter.ObjectCounter()
        counter.set_args(view_img=False, reg_pts=points, classes_names
            =filter_dict_by_keys(model.names,classes_to_count) , draw_tracks=True)
        counters.append(counter)
    return counters

counters = [initialize_counters(model, region_points) for model in models] 

# Define a function to process each lane
def process_lane(cap, model, counters, dist):
    while cap.isOpened():
        success, im0 = cap.read()
        if not success:
            print("Video frame is empty or video processing has been successfully completed.")
        im0 = cv2.resize(im0, (1080, 750))
        timer=0
        for counter, points in zip(counters, region_points):
            tracks = model.track(im0, persist=True, show=False, classes=classes_to_count)
            im0 = counter.start_counting(im0, tracks)
            px = pd.DataFrame(tracks[0].boxes.data.detach().cpu().numpy()).astype("float")
            counts = {0: 0, 1: 0, 2: 0, 3: 0, 5: 0, 7: 0}
            for _, row in px.iterrows():
                class_num = row[6]
                if class_num in classes_to_count:
                    counts[class_num] += 1 
            timer = timer+sum([
                2.5 + dist if counts.get(2, 0) != 0 else 0,
                3.5 + dist if counts.get(3, 0) != 0 else 0,
                2.5 + dist if counts.get(5, 0) != 0 else 0,
                3.5 + dist if counts.get(7, 0) != 0 else 0
            ])
            if success == True: 
            # Display the resulting frame 
                cv2.imshow('Frame', im0) 
          
            # Press Q on keyboard to exit 
            if cv2.waitKey(25) & 0xFF == ord('q'): 
                break
  
            # Break the loop 
            else: 
                break
        print(timer)
        yield timer

# Define a token passing function
def timerTokenPasser(timer_gen):
    while True:
        t1 = next(timer_gen)
        print("Lane t1 is open. Passing token to t2...")
        time.sleep(min(t1/3 ,20) )
        t2 = next(timer_gen)
        print("Lane t2 is open. Passing token to t3...")
        time.sleep(min(t2/3,20))
        t3 = next(timer_gen)
        print("Lane t3 is open. Passing token to t4...")
        time.sleep(min(t3/3,20))
        t4 = next(timer_gen)
        print("Lane t4 is open. Passing token to t1...")
        time.sleep(min(t4/3,20))

# Process each lane and collect the timer values
timer_gens = [process_lane(caps[i], models[i], counters[i], 2 * i)  for i in range(4)]

# Pass the generator functions to timerTokenPasser
for timer_gen in timer_gens:
    timerTokenPasser(timer_gen)

# Release resources
for cap in caps:
    cap.release()

cv2.destroyAllWindows()
# Out:
# {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
#
# 0: 448x640 8 cars, 1 bus, 78.5ms
# Speed: 5.0ms preprocess, 78.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 8 cars, 1 bus, 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 10 cars, 2 buss, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 10 cars, 2 buss, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 13 cars, 1 bus, 1 truck, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 8.5
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 13 cars, 1 bus, 1 truck, 72.9ms
# Speed: 3.0ms preprocess, 72.9ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 8.5
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 13 cars, 2 buss, 67.5ms
# Speed: 3.0ms preprocess, 67.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 13 cars, 1 bus, 1 truck, 67.8ms
# Speed: 3.0ms preprocess, 67.8ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 8.5
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 13 cars, 2 buss, 82.6ms
# Speed: 2.0ms preprocess, 82.6ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 14 cars, 1 bus, 61.5ms
# Speed: 3.0ms preprocess, 61.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 13 cars, 2 buss, 52.9ms
# Speed: 2.0ms preprocess, 52.9ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 14 cars, 2 buss, 48.0ms
# Speed: 2.0ms preprocess, 48.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 14 cars, 1 bus, 1 truck, 52.0ms
# Speed: 5.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 8.5
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 14 cars, 1 bus, 1 truck, 51.9ms
# Speed: 2.0ms preprocess, 51.9ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 8.5
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 14 cars, 1 bus, 1 truck, 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 8.5
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 15 cars, 1 bus, 51.5ms
# Speed: 4.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 15 cars, 1 bus, 51.5ms
# Speed: 3.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 15 cars, 1 bus, 52.5ms
# Speed: 2.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 15 cars, 1 bus, 75.5ms
# Speed: 4.0ms preprocess, 75.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 15 cars, 1 bus, 50.5ms
# Speed: 2.0ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 16 cars, 1 bus, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 16 cars, 1 bus, 52.5ms
# Speed: 3.0ms preprocess, 52.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 16 cars, 1 bus, 56.5ms
# Speed: 3.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 16 cars, 1 bus, 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 16 cars, 1 bus, 52.0ms
# Speed: 1.0ms preprocess, 52.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 16 cars, 1 bus, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 16 cars, 1 bus, 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 16 cars, 1 bus, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 16 cars, 1 bus, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 16 cars, 1 bus, 50.5ms
# Speed: 3.0ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 16 cars, 1 bus, 66.3ms
# Speed: 4.0ms preprocess, 66.3ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 16 cars, 1 bus, 64.0ms
# Speed: 3.0ms preprocess, 64.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 16 cars, 1 bus, 62.8ms
# Speed: 4.0ms preprocess, 62.8ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 16 cars, 1 bus, 93.8ms
# Speed: 2.0ms preprocess, 93.8ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 16 cars, 1 bus, 67.7ms
# Speed: 2.0ms preprocess, 67.7ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 16 cars, 2 buss, 53.5ms
# Speed: 5.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 16 cars, 2 buss, 64.5ms
# Speed: 2.0ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 16 cars, 2 buss, 66.8ms
# Speed: 3.0ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 15 cars, 3 buss, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 15 cars, 3 buss, 76.4ms
# Speed: 2.0ms preprocess, 76.4ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 16 cars, 2 buss, 54.6ms
# Speed: 2.0ms preprocess, 54.6ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 16 cars, 2 buss, 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 16 cars, 2 buss, 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 16 cars, 2 buss, 50.1ms
# Speed: 2.0ms preprocess, 50.1ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 16 cars, 2 buss, 50.0ms
# Speed: 5.0ms preprocess, 50.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 16 cars, 2 buss, 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 16 cars, 2 buss, 48.6ms
# Speed: 3.0ms preprocess, 48.6ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 16 cars, 2 buss, 59.1ms
# Speed: 2.0ms preprocess, 59.1ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 16 cars, 2 buss, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 16 cars, 2 buss, 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 16 cars, 2 buss, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 16 cars, 2 buss, 52.0ms
# Speed: 3.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 16 cars, 2 buss, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 16 cars, 2 buss, 55.0ms
# Speed: 3.0ms preprocess, 55.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 16 cars, 2 buss, 68.0ms
# Speed: 3.0ms preprocess, 68.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 16 cars, 2 buss, 49.0ms
# Speed: 2.0ms preprocess, 49.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 16 cars, 2 buss, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 16 cars, 2 buss, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 16 cars, 2 buss, 54.0ms
# Speed: 1.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 16 cars, 2 buss, 62.5ms
# Speed: 1.0ms preprocess, 62.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 16 cars, 2 buss, 58.5ms
# Speed: 2.4ms preprocess, 58.5ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 16 cars, 2 buss, 52.5ms
# Speed: 3.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 16 cars, 2 buss, 49.0ms
# Speed: 2.0ms preprocess, 49.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 16 cars, 2 buss, 52.0ms
# Speed: 3.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 15 cars, 3 buss, 54.1ms
# Speed: 2.0ms preprocess, 54.1ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 15 cars, 3 buss, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 15 cars, 3 buss, 50.5ms
# Speed: 4.0ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 15 cars, 3 buss, 52.9ms
# Speed: 4.0ms preprocess, 52.9ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 15 cars, 3 buss, 62.5ms
# Speed: 2.0ms preprocess, 62.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 15 cars, 3 buss, 61.1ms
# Speed: 2.0ms preprocess, 61.1ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 15 cars, 3 buss, 54.5ms
# Speed: 5.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 15 cars, 3 buss, 52.5ms
# Speed: 2.0ms preprocess, 52.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 14 cars, 3 buss, 52.5ms
# Speed: 2.0ms preprocess, 52.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 14 cars, 3 buss, 50.6ms
# Speed: 5.0ms preprocess, 50.6ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 14 cars, 3 buss, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 14 cars, 3 buss, 49.0ms
# Speed: 1.0ms preprocess, 49.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 14 cars, 3 buss, 51.6ms
# Speed: 3.0ms preprocess, 51.6ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 14 cars, 3 buss, 82.0ms
# Speed: 2.0ms preprocess, 82.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 14 cars, 3 buss, 49.5ms
# Speed: 4.0ms preprocess, 49.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 14 cars, 3 buss, 47.5ms
# Speed: 3.0ms preprocess, 47.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 14 cars, 3 buss, 47.5ms
# Speed: 2.0ms preprocess, 47.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 14 cars, 3 buss, 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 14 cars, 3 buss, 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 14 cars, 3 buss, 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 14 cars, 3 buss, 52.9ms
# Speed: 2.0ms preprocess, 52.9ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 14 cars, 3 buss, 51.0ms
# Speed: 4.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 14 cars, 3 buss, 50.6ms
# Speed: 3.0ms preprocess, 50.6ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 14 cars, 3 buss, 50.5ms
# Speed: 1.0ms preprocess, 50.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 13 cars, 3 buss, 1 truck, 53.5ms
# Speed: 4.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 8.5
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 13 cars, 3 buss, 1 truck, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 8.5
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 14 cars, 3 buss, 51.5ms
# Speed: 2.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 14 cars, 3 buss, 47.5ms
# Speed: 3.0ms preprocess, 47.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 13 cars, 3 buss, 1 truck, 50.5ms
# Speed: 2.0ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 8.5
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 13 cars, 3 buss, 1 truck, 47.0ms
# Speed: 2.0ms preprocess, 47.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 8.5
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 13 cars, 3 buss, 1 truck, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 8.5
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 13 cars, 3 buss, 1 truck, 50.0ms
# Speed: 3.0ms preprocess, 50.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 8.5
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 13 cars, 3 buss, 1 truck, 49.5ms
# Speed: 3.0ms preprocess, 49.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 8.5
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 14 cars, 3 buss, 53.0ms
# Speed: 3.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 14 cars, 3 buss, 65.6ms
# Speed: 3.0ms preprocess, 65.6ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 14 cars, 3 buss, 51.5ms
# Speed: 4.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 14 cars, 3 buss, 51.0ms
# Speed: 5.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 14 cars, 3 buss, 52.0ms
# Speed: 3.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 14 cars, 3 buss, 51.0ms
# Speed: 4.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 14 cars, 3 buss, 54.0ms
# Speed: 4.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 14 cars, 3 buss, 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 14 cars, 3 buss, 50.5ms
# Speed: 3.0ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 14 cars, 3 buss, 47.5ms
# Speed: 4.0ms preprocess, 47.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 14 cars, 3 buss, 50.5ms
# Speed: 5.0ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 14 cars, 3 buss, 48.5ms
# Speed: 2.9ms preprocess, 48.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 14 cars, 3 buss, 49.0ms
# Speed: 1.0ms preprocess, 49.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 14 cars, 3 buss, 51.0ms
# Speed: 6.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 15 cars, 3 buss, 51.0ms
# Speed: 5.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 15 cars, 3 buss, 49.0ms
# Speed: 3.0ms preprocess, 49.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 15 cars, 3 buss, 52.0ms
# Speed: 3.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 15 cars, 3 buss, 49.5ms
# Speed: 4.0ms preprocess, 49.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 15 cars, 3 buss, 50.7ms
# Speed: 1.0ms preprocess, 50.7ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 15 cars, 3 buss, 49.5ms
# Speed: 5.0ms preprocess, 49.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 16 cars, 2 buss, 51.0ms
# Speed: 2.0ms preprocess, 51.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 16 cars, 2 buss, 51.5ms
# Speed: 4.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 16 cars, 2 buss, 51.0ms
# Speed: 3.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 16 cars, 2 buss, 50.0ms
# Speed: 6.0ms preprocess, 50.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 16 cars, 2 buss, 51.0ms
# Speed: 5.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 16 cars, 2 buss, 46.0ms
# Speed: 2.0ms preprocess, 46.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 16 cars, 2 buss, 52.5ms
# Speed: 2.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 16 cars, 2 buss, 51.3ms
# Speed: 2.0ms preprocess, 51.3ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 16 cars, 2 buss, 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 17 cars, 2 buss, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 17 cars, 2 buss, 62.5ms
# Speed: 2.0ms preprocess, 62.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 17 cars, 2 buss, 53.0ms
# Speed: 3.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 17 cars, 2 buss, 52.0ms
# Speed: 3.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 17 cars, 2 buss, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 17 cars, 2 buss, 51.0ms
# Speed: 3.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 17 cars, 2 buss, 51.0ms
# Speed: 3.2ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 17 cars, 2 buss, 48.5ms
# Speed: 2.0ms preprocess, 48.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 17 cars, 2 buss, 48.6ms
# Speed: 2.0ms preprocess, 48.6ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 17 cars, 2 buss, 50.5ms
# Speed: 2.0ms preprocess, 50.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 16 cars, 3 buss, 51.0ms
# Speed: 2.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 16 cars, 3 buss, 51.0ms
# Speed: 5.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 16 cars, 3 buss, 49.0ms
# Speed: 2.0ms preprocess, 49.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 16 cars, 3 buss, 51.0ms
# Speed: 4.5ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 16 cars, 3 buss, 49.6ms
# Speed: 3.0ms preprocess, 49.6ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 16 cars, 3 buss, 50.5ms
# Speed: 4.0ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 16 cars, 3 buss, 46.5ms
# Speed: 3.0ms preprocess, 46.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 16 cars, 3 buss, 51.0ms
# Speed: 2.0ms preprocess, 51.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 16 cars, 3 buss, 50.0ms
# Speed: 3.0ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 16 cars, 3 buss, 52.0ms
# Speed: 5.0ms preprocess, 52.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 16 cars, 3 buss, 50.5ms
# Speed: 2.0ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 16 cars, 3 buss, 47.5ms
# Speed: 3.0ms preprocess, 47.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 16 cars, 3 buss, 51.5ms
# Speed: 2.0ms preprocess, 51.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 17 cars, 2 buss, 52.5ms
# Speed: 4.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 18 cars, 2 buss, 51.5ms
# Speed: 5.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 18 cars, 2 buss, 50.5ms
# Speed: 3.0ms preprocess, 50.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 18 cars, 2 buss, 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 18 cars, 2 buss, 50.0ms
# Speed: 3.0ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 18 cars, 2 buss, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 18 cars, 2 buss, 52.0ms
# Speed: 4.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 18 cars, 2 buss, 53.0ms
# Speed: 3.0ms preprocess, 53.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 19 cars, 2 buss, 49.0ms
# Speed: 2.0ms preprocess, 49.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 19 cars, 2 buss, 68.0ms
# Speed: 3.0ms preprocess, 68.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 19 cars, 2 buss, 59.4ms
# Speed: 3.0ms preprocess, 59.4ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 19 cars, 2 buss, 49.0ms
# Speed: 4.0ms preprocess, 49.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 19 cars, 2 buss, 50.0ms
# Speed: 4.0ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 19 cars, 2 buss, 55.0ms
# Speed: 2.5ms preprocess, 55.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 19 cars, 2 buss, 62.0ms
# Speed: 1.0ms preprocess, 62.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 19 cars, 2 buss, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 19 cars, 2 buss, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 19 cars, 2 buss, 52.1ms
# Speed: 3.0ms preprocess, 52.1ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 19 cars, 2 buss, 52.5ms
# Speed: 4.0ms preprocess, 52.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 19 cars, 2 buss, 53.5ms
# Speed: 4.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 19 cars, 2 buss, 55.5ms
# Speed: 3.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 19 cars, 2 buss, 53.5ms
# Speed: 5.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 19 cars, 2 buss, 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 19 cars, 2 buss, 53.5ms
# Speed: 4.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 19 cars, 2 buss, 53.5ms
# Speed: 1.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 19 cars, 2 buss, 53.0ms
# Speed: 3.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 19 cars, 2 buss, 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 19 cars, 2 buss, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 19 cars, 2 buss, 70.2ms
# Speed: 2.0ms preprocess, 70.2ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 19 cars, 2 buss, 77.9ms
# Speed: 2.0ms preprocess, 77.9ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 19 cars, 2 buss, 125.2ms
# Speed: 2.0ms preprocess, 125.2ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 19 cars, 2 buss, 94.9ms
# Speed: 2.0ms preprocess, 94.9ms inference, 3.2ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 19 cars, 2 buss, 67.7ms
# Speed: 3.0ms preprocess, 67.7ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 19 cars, 2 buss, 111.1ms
# Speed: 5.0ms preprocess, 111.1ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 18 cars, 3 buss, 81.8ms
# Speed: 4.0ms preprocess, 81.8ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 18 cars, 3 buss, 99.6ms
# Speed: 2.0ms preprocess, 99.6ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 18 cars, 3 buss, 127.4ms
# Speed: 5.0ms preprocess, 127.4ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 18 cars, 3 buss, 94.5ms
# Speed: 2.0ms preprocess, 94.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 18 cars, 3 buss, 83.5ms
# Speed: 2.0ms preprocess, 83.5ms inference, 3.5ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 18 cars, 3 buss, 119.8ms
# Speed: 3.0ms preprocess, 119.8ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 19 cars, 2 buss, 104.0ms
# Speed: 4.2ms preprocess, 104.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 18 cars, 3 buss, 96.6ms
# Speed: 4.0ms preprocess, 96.6ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 18 cars, 3 buss, 100.3ms
# Speed: 2.0ms preprocess, 100.3ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 18 cars, 3 buss, 89.5ms
# Speed: 2.0ms preprocess, 89.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 18 cars, 3 buss, 107.4ms
# Speed: 3.0ms preprocess, 107.4ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 17 cars, 3 buss, 1 truck, 131.6ms
# Speed: 6.3ms preprocess, 131.6ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 8.5
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 18 cars, 3 buss, 81.5ms
# Speed: 3.0ms preprocess, 81.5ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 18 cars, 3 buss, 101.3ms
# Speed: 2.0ms preprocess, 101.3ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 19 cars, 2 buss, 104.4ms
# Speed: 3.0ms preprocess, 104.4ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 18 cars, 3 buss, 107.6ms
# Speed: 2.0ms preprocess, 107.6ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 18 cars, 3 buss, 156.4ms
# Speed: 7.0ms preprocess, 156.4ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 18 cars, 3 buss, 100.9ms
# Speed: 3.0ms preprocess, 100.9ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 18 cars, 3 buss, 101.6ms
# Speed: 6.0ms preprocess, 101.6ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 18 cars, 3 buss, 117.7ms
# Speed: 2.0ms preprocess, 117.7ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 18 cars, 3 buss, 91.7ms
# Speed: 3.0ms preprocess, 91.7ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 18 cars, 3 buss, 113.2ms
# Speed: 4.0ms preprocess, 113.2ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 18 cars, 3 buss, 199.1ms
# Speed: 3.0ms preprocess, 199.1ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 18 cars, 3 buss, 79.5ms
# Speed: 2.0ms preprocess, 79.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 18 cars, 3 buss, 101.4ms
# Speed: 3.0ms preprocess, 101.4ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 18 cars, 3 buss, 79.5ms
# Speed: 2.0ms preprocess, 79.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 18 cars, 3 buss, 90.8ms
# Speed: 2.0ms preprocess, 90.8ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 18 cars, 3 buss, 86.5ms
# Speed: 3.0ms preprocess, 86.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 18 cars, 3 buss, 99.1ms
# Speed: 3.0ms preprocess, 99.1ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 17 cars, 3 buss, 90.0ms
# Speed: 5.0ms preprocess, 90.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 17 cars, 3 buss, 104.4ms
# Speed: 3.0ms preprocess, 104.4ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 17 cars, 3 buss, 99.3ms
# Speed: 3.0ms preprocess, 99.3ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 17 cars, 3 buss, 166.1ms
# Speed: 32.7ms preprocess, 166.1ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 17 cars, 3 buss, 148.9ms
# Speed: 3.0ms preprocess, 148.9ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 17 cars, 3 buss, 67.5ms
# Speed: 3.0ms preprocess, 67.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 17 cars, 3 buss, 51.0ms
# Speed: 2.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 17 cars, 3 buss, 59.5ms
# Speed: 1.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 17 cars, 3 buss, 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 17 cars, 3 buss, 56.2ms
# Speed: 2.0ms preprocess, 56.2ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 17 cars, 3 buss, 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 17 cars, 3 buss, 51.5ms
# Speed: 4.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 17 cars, 3 buss, 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 17 cars, 3 buss, 55.5ms
# Speed: 4.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 17 cars, 3 buss, 56.0ms
# Speed: 4.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 17 cars, 3 buss, 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 17 cars, 3 buss, 53.5ms
# Speed: 3.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 17 cars, 3 buss, 51.5ms
# Speed: 3.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 17 cars, 3 buss, 50.5ms
# Speed: 3.0ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 17 cars, 3 buss, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 17 cars, 3 buss, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 17 cars, 3 buss, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 17 cars, 3 buss, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 17 cars, 3 buss, 53.0ms
# Speed: 5.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 17 cars, 3 buss, 55.0ms
# Speed: 3.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 17 cars, 3 buss, 63.2ms
# Speed: 1.4ms preprocess, 63.2ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 17 cars, 3 buss, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 17 cars, 3 buss, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 17 cars, 3 buss, 59.0ms
# Speed: 2.5ms preprocess, 59.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 17 cars, 3 buss, 66.7ms
# Speed: 2.5ms preprocess, 66.7ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 17 cars, 3 buss, 72.0ms
# Speed: 2.0ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 17 cars, 3 buss, 52.0ms
# Speed: 4.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 17 cars, 3 buss, 57.0ms
# Speed: 4.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 17 cars, 3 buss, 56.0ms
# Speed: 4.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 17 cars, 3 buss, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 17 cars, 3 buss, 52.0ms
# Speed: 3.0ms preprocess, 52.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 17 cars, 3 buss, 78.5ms
# Speed: 3.0ms preprocess, 78.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 17 cars, 3 buss, 54.0ms
# Speed: 4.0ms preprocess, 54.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 17 cars, 2 buss, 1 truck, 56.5ms
# Speed: 1.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 8.5
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 18 cars, 2 buss, 48.5ms
# Speed: 2.0ms preprocess, 48.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 17 cars, 3 buss, 62.5ms
# Speed: 3.0ms preprocess, 62.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 18 cars, 2 buss, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 18 cars, 2 buss, 53.6ms
# Speed: 6.0ms preprocess, 53.6ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 18 cars, 2 buss, 49.5ms
# Speed: 1.0ms preprocess, 49.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 17 cars, 2 buss, 1 truck, 61.4ms
# Speed: 5.0ms preprocess, 61.4ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 8.5
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 17 cars, 3 buss, 56.0ms
# Speed: 4.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 17 cars, 3 buss, 74.0ms
# Speed: 3.0ms preprocess, 74.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 17 cars, 3 buss, 53.0ms
# Speed: 4.0ms preprocess, 53.0ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 17 cars, 3 buss, 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 17 cars, 3 buss, 50.0ms
# Speed: 3.0ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 18 cars, 3 buss, 54.2ms
# Speed: 1.0ms preprocess, 54.2ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 18 cars, 3 buss, 53.5ms
# Speed: 3.0ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 18 cars, 3 buss, 51.6ms
# Speed: 4.0ms preprocess, 51.6ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 18 cars, 3 buss, 181.1ms
# Speed: 6.0ms preprocess, 181.1ms inference, 4.5ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 18 cars, 3 buss, 173.2ms
# Speed: 5.0ms preprocess, 173.2ms inference, 4.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 18 cars, 3 buss, 176.9ms
# Speed: 7.5ms preprocess, 176.9ms inference, 4.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 18 cars, 3 buss, 178.4ms
# Speed: 9.0ms preprocess, 178.4ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 18 cars, 3 buss, 181.1ms
# Speed: 7.0ms preprocess, 181.1ms inference, 5.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 18 cars, 3 buss, 176.1ms
# Speed: 8.0ms preprocess, 176.1ms inference, 4.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 19 cars, 2 buss, 178.1ms
# Speed: 7.0ms preprocess, 178.1ms inference, 5.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 18 cars, 3 buss, 179.2ms
# Speed: 8.0ms preprocess, 179.2ms inference, 4.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 19 cars, 2 buss, 176.3ms
# Speed: 6.4ms preprocess, 176.3ms inference, 4.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
#
# 0: 448x640 19 cars, 2 buss, 186.6ms
# Speed: 7.0ms preprocess, 186.6ms inference, 5.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t3 is open. Passing token to t4...
#
# 0: 448x640 18 cars, 2 buss, 1 truck, 179.2ms
# Speed: 6.0ms preprocess, 179.2ms inference, 4.0ms postprocess per image at shape (1, 3, 448, 640)
# 8.5
# Lane t4 is open. Passing token to t1...
#
# 0: 448x640 19 cars, 2 buss, 174.9ms
# Speed: 7.0ms preprocess, 174.9ms inference, 4.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t1 is open. Passing token to t2...
#
# 0: 448x640 19 cars, 2 buss, 179.3ms
# Speed: 26.0ms preprocess, 179.3ms inference, 5.0ms postprocess per image at shape (1, 3, 448, 640)
# 5.0
# Lane t2 is open. Passing token to t3...
# Video frame is empty or video processing has been successfully completed.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 97
#      95 # Pass the generator functions to timerTokenPasser
#      96 for timer_gen in timer_gens:
# ---> 97     timerTokenPasser(timer_gen)
#      99 # Release resources
#     100 for cap in caps:
#
# Cell In[1], line 85, in timerTokenPasser(timer_gen)
#      83 print("Lane t2 is open. Passing token to t3...")
#      84 time.sleep(min(t2/3,20))
# ---> 85 t3 = next(timer_gen)
#      86 print("Lane t3 is open. Passing token to t4...")
#      87 time.sleep(min(t3/3,20))
#
# Cell In[1], line 45, in process_lane(cap, model, counters, dist)
#      43 if not success:
#      44     print("Video frame is empty or video processing has been successfully completed.")
# ---> 45 im0 = cv2.resize(im0, (1080, 750))
#      46 timer=0
#      47 for counter, points in zip(counters, region_points):
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
from ultralytics import YOLO
from ultralytics.solutions import object_counter
import cv2
import pandas as pd
import time

# Load YOLO models
models = [YOLO("yolov8n.pt") for _ in range(4)]

# Open video captures for each lane
caps = [cv2.VideoCapture("highway.mp4") for _ in range(4)]

# Check if video captures are opened successfully
for cap in caps:
    assert cap.isOpened(), "Error reading video file"

# Define region points for three lanes spanning half of the screen
region_points = [
    [(20, 400), (540, 400), (520, 740), (20, 740)],     # Left half of the screen
    [(540, 400), (1060, 400), (1040, 740), (540, 740)], # Middle half of the screen
    [(20, 400), (1060, 400), (1040, 740), (20, 740)]    # Right half of the screen
]

# Initialize Object Counters for each lane and each region
counters = [[[object_counter.ObjectCounter() for _ in range(3)] for _ in range(3)] for _ in range(4)]
for i in range(4):
    for j in range(3):
        for k in range(3):
            counters[i][j][k].set_args(view_img=False, reg_pts=region_points[k], classes_names=models[i].names, draw_tracks=True)

# Define classes to count
classes_to_count = [2, 5, 7]  # Car, Motorcycle, Truck

# Define a function to process each lane
def process_lane(cap, models, counters):
    while cap.isOpened():
        success, im0 = cap.read()
        im0 = cv2.resize(im0, (1080, 750))
        if not success:
            print("Video frame is empty or video processing has been successfully completed.")
            break

        timers = []

        # Iterate over models, counters, and regions
        for i, (model, cnts) in enumerate(zip(models, counters)):
            for j, cnts_region in enumerate(cnts):
                counts = {0: 0, 1: 0, 2: 0, 3: 0, 5: 0, 7: 0}  # Initialize counters for the current region

                # Process frame with the current model and counter
                tracks = model.track(im0, persist=True, show=False, classes=classes_to_count)
                im0 = cnts_region[j].start_counting(im0, tracks)
                boxes_data = tracks[0].boxes.data.detach().cpu().numpy()

                # Iterate over detected objects and update counts
                for box in boxes_data:
                    class_num = int(box[6])
                    if class_num in classes_to_count:
                        counts[class_num] += 1

                # Calculate timer based on counts
                timer = (counts.get(2, 0) * 7) + (counts.get(3, 0) * 5) + (counts.get(5, 0) + counts.get(7, 0)) * 10
                timers.append(timer)

                print(f"Lane {i+1}, Region {j+1} Counts:", counts)

        # Yield timer value
        yield timers

# Define a token passing function
def token_passer(timer_gens):
    while True:
        for timer_gen in timer_gens:
            timers = next(timer_gen)
            total_time = sum(timers)
            print(f"Total time for passing token: {total_time} seconds")
            time.sleep(total_time)

# Generate timer generators for each lane
timer_gens = [process_lane(caps[i], models, counters[i]) for i in range(4)]

# Start token passing
# token_passer(timer_gens)

# Release resources
for cap in caps:
    cap.release()

cv2.destroyAllWindows()
# Out:
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.
# Region Counter Initiated.

# %%
import cv2
import numpy as np

# Given coordinates
x1 = 1200
y1 = 1024

# Calculate the center of the screen
center_x = x1 // 2
center_y = y1 // 2

# Calculate the coordinates for dividing the quarter
div_x1 = center_x
div_x2 = x1

# Calculate the height of the quarter
quarter_height = y1 - center_y

# Calculate the height of each part
part_height = quarter_height // 3

# Define region points for the lower-right quarter and its divisions
region_points = [(center_x, center_y), (x1, center_y), (x1, y1), (center_x, y1)]
division1_points = [(center_x, center_y), (x1, center_y), (x1, center_y + part_height), (center_x, center_y + part_height)]
division2_points = [(center_x, center_y + part_height), (x1, center_y + part_height), (x1, center_y + 2 * part_height), (center_x, center_y + 2 * part_height)]
division3_points = [(center_x, center_y + 2 * part_height), (x1, center_y + 2 * part_height), (x1, y1), (center_x, y1)]

# Create an image to visualize the regions
img = np.zeros((y1, x1, 3), dtype=np.uint8)

# Draw the region rectangles
cv2.polylines(img, [np.array(region_points)], isClosed=True, color=(255, 0, 0), thickness=2)
cv2.polylines(img, [np.array(division1_points)], isClosed=True, color=(0, 255, 0), thickness=2)
cv2.polylines(img, [np.array(division2_points)], isClosed=True, color=(0, 0, 255), thickness=2)
cv2.polylines(img, [np.array(division3_points)], isClosed=True, color=(255, 255, 0), thickness=2)

# Display the image
cv2.imshow("Quarter with Divisions", img)
cv2.waitKey(0)
cv2.destroyAllWindows()
